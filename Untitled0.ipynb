# %% [markdown]
# <a href="https://colab.research.google.com/github/dustin-kim80/dustin800512/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from fbprophet import Prophet
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()



#df = pd.read_csv("/drive/My Drive/일반비_rr.csv")
# Out:
#      <input type="file" id="files-df04b858-1e54-4233-9153-79e0ac6ed547" name="files[]" multiple disabled />
#      <output id="result-df04b858-1e54-4233-9153-79e0ac6ed547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 일반비_rr.csv to 일반비_rr.csv

# %%
print(uploaded)
# Out:
# {'일반비_rr.csv': b'ds,y\r\n2007-12-10,9.590761139\r\n2007-12-11,8.519590316\r\n2007-12-12,8.183676583\r\n2007-12-13,8.072467369\r\n2007-12-14,7.893572074\r\n2007-12-15,7.783640596\r\n2007-12-16,8.414052432\r\n2007-12-17,8.829226355\r\n2007-12-18,8.382518288\r\n2007-12-19,8.069655307\r\n2007-12-20,7.879291485\r\n2007-12-21,7.761744985\r\n2007-12-22,7.529406458\r\n2007-12-23,8.38526052\r\n2007-12-24,8.620110725\r\n2007-12-25,7.852439085\r\n2007-12-26,7.853993087\r\n2007-12-27,8.051978079\r\n2007-12-28,7.926602599\r\n2007-12-29,7.838343316\r\n2007-12-30,9.703144581\r\n2007-12-31,9.385972941\r\n2008-01-01,8.293799609\r\n2008-01-02,8.43468077\r\n2008-01-03,8.262042844\r\n2008-01-04,8.106816039\r\n2008-01-05,7.950149888\r\n2008-01-06,9.509259076\r\n2008-01-07,8.846784667\r\n2008-01-08,8.430545385\r\n2008-01-09,8.248267447\r\n2008-01-10,8.28172399\r\n2008-01-11,8.292798858\r\n2008-01-12,8.199189359\r\n2008-01-13,9.996522419\r\n2008-01-14,10.12707101\r\n2008-01-15,8.933796044\r\n2008-01-16,8.5
# ...

# %%
import io
data = io.BytesIO(uploaded['일반비_rr.csv'])

# %%
print(uploaded)
# Out:
# {'일반비_rr.csv': b'ds,y\r\n2007-12-10,9.590761139\r\n2007-12-11,8.519590316\r\n2007-12-12,8.183676583\r\n2007-12-13,8.072467369\r\n2007-12-14,7.893572074\r\n2007-12-15,7.783640596\r\n2007-12-16,8.414052432\r\n2007-12-17,8.829226355\r\n2007-12-18,8.382518288\r\n2007-12-19,8.069655307\r\n2007-12-20,7.879291485\r\n2007-12-21,7.761744985\r\n2007-12-22,7.529406458\r\n2007-12-23,8.38526052\r\n2007-12-24,8.620110725\r\n2007-12-25,7.852439085\r\n2007-12-26,7.853993087\r\n2007-12-27,8.051978079\r\n2007-12-28,7.926602599\r\n2007-12-29,7.838343316\r\n2007-12-30,9.703144581\r\n2007-12-31,9.385972941\r\n2008-01-01,8.293799609\r\n2008-01-02,8.43468077\r\n2008-01-03,8.262042844\r\n2008-01-04,8.106816039\r\n2008-01-05,7.950149888\r\n2008-01-06,9.509259076\r\n2008-01-07,8.846784667\r\n2008-01-08,8.430545385\r\n2008-01-09,8.248267447\r\n2008-01-10,8.28172399\r\n2008-01-11,8.292798858\r\n2008-01-12,8.199189359\r\n2008-01-13,9.996522419\r\n2008-01-14,10.12707101\r\n2008-01-15,8.933796044\r\n2008-01-16,8.5
# ...

# %%
import pandas as pd   
f= pd.read_csv(data , header = 0 )
print(f)
# Out:
#              ds          y
# 0    2007-12-10   9.590761
# 1    2007-12-11   8.519590
# 2    2007-12-12   8.183677
# 3    2007-12-13   8.072467
# 4    2007-12-14   7.893572
# ..          ...        ...
# 728  2010-01-14   8.614501
# 729  2010-01-15   8.658866
# 730  2010-01-16   8.779404
# 731  2010-01-17  11.007933
# 732  2010-01-18   9.753246
#
# [733 rows x 2 columns]

# %%
f.plot(x='ds', y='y', figsize=(16, 8))

# %%
model = Prophet()

model.fit(f)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=365)

forecast = model.predict(future)

forecast.tail()
# Out:
#              ds     trend  ...  multiplicative_terms_upper       yhat
# 1093 2011-01-14  9.363736  ...                         0.0   9.962320
# 1094 2011-01-15  9.366338  ...                         0.0   9.773414
# 1095 2011-01-16  9.368940  ...                         0.0  10.171649
# 1096 2011-01-17  9.371543  ...                         0.0  10.458895
# 1097 2011-01-18  9.374145  ...                         0.0  10.239401
#
# [5 rows x 19 columns]

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)
